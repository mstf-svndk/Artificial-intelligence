# %%
pip install gTTS
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from gtts import gTTS
import os

myText="Merhaba ben Mustafa. Sen Kimsin?"

output=gTTS(text=myText,lang="tr", slow=False)

output.save("outputtr.mp3") 

# Bir yazıyı istediğimiz şekilde okutabiliyoruz.
# kendi sitesinden seçeneklere bakılabiliyor

# %%
from IPython.display import Audio
audio=Audio(filename="outputtr.mp3")
audio
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
